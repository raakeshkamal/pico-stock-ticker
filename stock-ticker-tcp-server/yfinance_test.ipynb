# %%
import yfinance as yf
dat = yf.Ticker("AMZN")

# %%
import json
print(json.dumps(dat.info, indent=4))
# Out:
# {
#     "address1": "410 Terry Avenue North",
#     "city": "Seattle",
#     "state": "WA",
#     "zip": "98109-5210",
#     "country": "United States",
#     "phone": "206 266 1000",
#     "website": "https://www.aboutamazon.com",
#     "industry": "Internet Retail",
#     "industryKey": "internet-retail",
#     "industryDisp": "Internet Retail",
#     "sector": "Consumer Cyclical",
#     "sectorKey": "consumer-cyclical",
#     "sectorDisp": "Consumer Cyclical",
# ...

# %%
dat = yf.Ticker('USDJPY=X')
dat.info
dat.history(period='1d', interval='1h')
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-06-09 00:00:00+01:00  144.690994  144.746994  144.593994  144.692993
# 2025-06-09 01:00:00+01:00  144.690002  144.947998  144.574005  144.932007
# 2025-06-09 02:00:00+01:00  144.938004  144.938995  144.470001  144.542007
# 2025-06-09 03:00:00+01:00  144.541000  144.570999  144.345001  144.496002
# 2025-06-09 04:00:00+01:00  144.494003  144.509995  144.348999  144.492004
# 2025-06-09 05:00:00+01:00  144.488998  144.494995  144.345993  144.376999
# 2025-06-09 06:00:00+01:00  144.378998  144.496002  144.347000  144.412994
# 2025-06-09 07:00:00+01:00  144.412003  144.464005  144.195007  144.209000
# 2025-06-09 08:00:00+01:00  144.207993  144.298996  144.098007  144.143005
# 2025-06-09 09:00:00+01:00  144.143005  144.175995  144.031998  144.154999
# 2025-06-09 10:00:00+01:00  144.153000  144.166000  143.970001  144.102997
# ...
